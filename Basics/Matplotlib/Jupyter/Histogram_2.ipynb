# %%
# %matplotlib notebook
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_columns', 500)
data_c = []
data_c = pd.read_excel('/home/rohyth/Downloads/UN_MigFlow_All_CountryFiles/Canada.xlsx',sheet_name='Canada by Citizenship')


data_c.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
data_c.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
data_c.set_index('Country', inplace=True)
data_c['Total'] = data_c.sum(axis=1)
data_c.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  \
# Country
# Afghanistan       39    47    71   340   496   741   828  1076  1028  1378
# Albania            0     0     0     0     1     2     2     3     3    21
# Algeria           71    69    63    44    69   132   242   434   491   872
# American Samoa     0     0     0     0     0     1     0     1     2     0
# Andorra            0     0     0     0     2     0     0     0     3     0
#
# ...

# %%
import numpy as np

count , bin_edges = np.histogram(data_c[2013])
data_c[2013].plot(kind='hist' , xticks = bin_edges)

plt.title('Histogram')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="590">
